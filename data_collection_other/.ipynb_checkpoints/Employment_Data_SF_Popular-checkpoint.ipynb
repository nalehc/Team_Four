# %%
import os
import csv
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
year_list = []
industry_list = []
quarter_list = []
industry_type_list = []
month1_list = []
month2_list = []
month3_list = []
total_wages_list = []

for each_csv_file in glob.glob("*.csv"):
    print(each_csv_file)
    
    csvpath = each_csv_file
    
    with open(csvpath, newline='') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',')
        for row in csvreader:
            
            if row[0] == "06075":
                year_list.append(row[5])
                industry_list.append(row[10])
                industry_type_list.append(row[9])
                quarter_list.append(row[6])
                month1_list.append(row[14])
                month2_list.append(row[15])
                month3_list.append(row[16])
                total_wages_list.append(row[17])
                
    csvfile.close()
print("Completed data collection")

collected_data_dict = {"Year": year_list, "Industry": industry_list, "Industry Type": industry_type_list,
                      "Quarter": quarter_list, "Emp Level Month #1": month1_list, "Emp Level Month #2": month2_list, "Emp Level Month #3": month3_list,
                      "Total Wages Collected": total_wages_list}
        
collected_data_df = pd.DataFrame(collected_data_dict)
# Out:
# 2004.q1-q4 51 Information.csv
# 2004.q1-q4 52 Finance and insurance.csv
# 2004.q1-q4 54 Professional and technical services.csv
# 2005.q1-q4 51 Information.csv
# 2005.q1-q4 52 Finance and insurance.csv
# 2005.q1-q4 54 Professional and technical services.csv
# 2006.q1-q4 51 Information.csv
# 2006.q1-q4 52 Finance and insurance.csv
# 2006.q1-q4 54 Professional and technical services.csv
# 2007.q1-q4 51 Information.csv
# 2007.q1-q4 52 Finance and insurance.csv
# 2007.q1-q4 54 Professional and technical services.csv
# 2008.q1-q4 51 Information.csv
# 2008.q1-q4 52 Finance and insurance.csv
# 2008.q1-q4 54 Professional and technical services.csv
# 2009.q1-q4 51 Information.csv
# 2009.q1-q4 52 Finance and insurance.csv
# 2009.q1-q4 54 Professional and technical services.csv
# 2010.q1-q4 51 Information.csv
# 2010.q1-q4 52 Finance and insurance.csv
# 2010.q1-q4 54 Professional and technical services.csv
# 2011.q1-q4 51 Information.csv
# 2011.q1-q4 52 Finance and insurance.csv
# 2011.q1-q4 54 Professional and technical services.csv
# 2012.q1-q4 51 Information.csv
# 2012.q1-q4 52 Finance and insurance.csv
# 2012.q1-q4 54 Professional and technical services.csv
# 2013.q1-q4 51 Information.csv
# 2013.q1-q4 52 Finance and insurance.csv
# 2013.q1-q4 54 Professional and technical services.csv
# 2014.q1-q4 51 Information.csv
# 2014.q1-q4 52 Finance and insurance.csv
# 2014.q1-q4 54 Professional and technical services.csv
# 2015.q1-q4 51 Information.csv
# 2015.q1-q4 52 Finance and insurance.csv
# 2015.q1-q4 54 Professional and technical services.csv
# 2016.q1-q4 51 NAICS 51 Information.csv
# 2016.q1-q4 52 NAICS 52 Finance and insurance.csv
# 2016.q1-q4 54 NAICS 54 Professional and technical services.csv
# 2017.q1-q2 51 NAICS 51 Information.csv
# 2017.q1-q2 52 NAICS 52 Finance and insurance.csv
# 2017.q1-q2 54 NAICS 54 Professional and technical services.csv
# Completed data collection

# %%
collected_data_df = collected_data_df[['Year', 'Industry', 'Industry Type', 'Quarter', 'Emp Level Month #1',
                                      'Emp Level Month #2', 'Emp Level Month #3', 'Total Wages Collected']]
collected_data_df = collected_data_df.sort_values(['Year', 'Industry']).reset_index(drop=True)

#Dropping government related jobs
collected_data_df_mod = collected_data_df.loc[collected_data_df['Industry Type']=='Private'].reset_index(drop=True)

# %%
collected_data_df_mod['Emp Level Month #1'] = pd.to_numeric(collected_data_df_mod['Emp Level Month #1'])
collected_data_df_mod['Emp Level Month #2'] = pd.to_numeric(collected_data_df_mod['Emp Level Month #2'])
collected_data_df_mod['Emp Level Month #3'] = pd.to_numeric(collected_data_df_mod['Emp Level Month #3'])
collected_data_df_mod['Total Wages Collected'] = pd.to_numeric(collected_data_df_mod['Total Wages Collected'])

# %%
# Grouping the year and inudstry, then calculating the mean between the ROWS.  Which will then be used in the 
# function to calculate the mean between columns

group_year = collected_data_df_mod.groupby(["Year", "Industry"]).mean()
group_year.head()
# Out:
#                                           Emp Level Month #1  \
# Year Industry
# 2004 Finance and insurance                          45521.00
#      Information                                    19182.75
#      Professional and technical services            57273.75
# 2005 Finance and insurance                          45626.75
#      Information                                    17056.50
#
#                                           Emp Level Month #2  \
# Year Industry
# 2004 Finance and insurance                          45722.25
#      Information                                    19289.50
#      Professional and technical services            57352.50
# 2005 Finance and insurance                          45828.50
#      Information                                    17117.75
#
#                                           Emp Level Month #3  \
# Year Industry
# 2004 Finance and insurance                          45676.00
#      Information                                    19104.75
#      Professional and technical services            57616.75
# 2005 Finance and insurance                          45848.50
#      Information                                    17116.00
#
#                                           Total Wages Collected
# Year Industry
# 2004 Finance and insurance                         1.744442e+09
#      Information                                   3.748954e+08
#      Professional and technical services           1.289071e+09
# 2005 Finance and insurance                         1.866978e+09
#      Information                                   3.625047e+08

# %%
group_year["Yearly Average Emp"] = (group_year['Emp Level Month #1']+group_year['Emp Level Month #2']+group_year['Emp Level Month #3'])/3

# %%
blah = group_year.groupby("Year").sum()
blah.head()
# Out:
#       Emp Level Month #1  Emp Level Month #2  Emp Level Month #3  \
# Year
# 2004           121977.50           122364.25           122397.50
# 2005           125181.75           125829.75           126207.25
# 2006           131654.75           132640.00           133401.00
# 2007           138938.75           139904.00           140291.00
# 2008           141025.75           141043.50           140903.00
#
#       Total Wages Collected  Yearly Average Emp
# Year
# 2004           3.408409e+09       122246.416667
# 2005           3.787846e+09       125739.583333
# 2006           4.222129e+09       132565.250000
# 2007           4.696214e+09       139711.250000
# 2008           4.751812e+09       140990.750000

# %%
blah = blah.rename(columns={"Yearly Average Emp": "Yearly Total Emp"})
blah
# Out:
#       Emp Level Month #1  Emp Level Month #2  Emp Level Month #3  \
# Year
# 2004           121977.50           122364.25           122397.50
# 2005           125181.75           125829.75           126207.25
# 2006           131654.75           132640.00           133401.00
# 2007           138938.75           139904.00           140291.00
# 2008           141025.75           141043.50           140903.00
# 2009           133297.50           132470.00           132160.00
# 2010           129805.00           130003.25           130734.50
# 2011           138721.00           139493.00           140340.00
# 2012           150959.75           151927.75           152835.25
# 2013           157191.25           158393.25           159041.25
# 2014           170921.25           172127.50           173403.50
# 2015           185938.75           187138.25           188093.50
# 2016           200973.75           201838.00           202575.50
# 2017           201743.00           203096.00           205107.00
#
#       Total Wages Collected  Yearly Total Emp
# Year
# 2004           3.408409e+09     122246.416667
# 2005           3.787846e+09     125739.583333
# 2006           4.222129e+09     132565.250000
# 2007           4.696214e+09     139711.250000
# 2008           4.751812e+09     140990.750000
# 2009           4.261833e+09     132642.500000
# 2010           4.353893e+09     130180.916667
# 2011           4.952191e+09     139518.000000
# 2012           5.529164e+09     151907.583333
# 2013           5.799092e+09     158208.583333
# 2014           6.975372e+09     172150.750000
# 2015           7.819812e+09     187056.833333
# 2016           8.687504e+09     201795.750000
# 2017           9.556291e+09     203315.333333

# %%
percentage_change = blah.pct_change()

# %%
percentage_change_df = percentage_change[["Total Wages Collected", "Yearly Total Emp"]]

# %%
percentage_change_df = percentage_change_df.rename(columns={"Total Wages Collected": "Percentage Change (Wages)",
                                                           "Yearly Total Emp": "Percentage Change (Emp. Level)"})

# %%
percentage_change_df = percentage_change_df.reset_index()
percentage_change_df
# Out:
#     Year  Percentage Change (Wages)  Percentage Change (Emp. Level)
# 0   2004                        NaN                             NaN
# 1   2005                   0.111324                        0.028575
# 2   2006                   0.114652                        0.054284
# 3   2007                   0.112286                        0.053906
# 4   2008                   0.011839                        0.009158
# 5   2009                  -0.103114                       -0.059211
# 6   2010                   0.021601                       -0.018558
# 7   2011                   0.137417                        0.071724
# 8   2012                   0.116509                        0.088803
# 9   2013                   0.048819                        0.041479
# 10  2014                   0.202839                        0.088125
# 11  2015                   0.121060                        0.086587
# 12  2016                   0.110961                        0.078794
# 13  2017                   0.100004                        0.007530

# %%
fig, ax1 = plt.subplots(1, sharex=True, sharey= True)
fig.suptitle("Percentage Change (Other Common SF Jobs)", fontsize=16,
             fontweight="bold")

#ax1.set_xlim(min(year), max(year))
ax1.plot(percentage_change_df['Year'], percentage_change_df['Percentage Change (Wages)'], linewidth=1, marker="o", markersize=8)
ax1.plot(percentage_change_df['Year'], percentage_change_df['Percentage Change (Emp. Level)'], linewidth=1, marker="o", markersize=8)
ax1.set_ylabel("Percentage Change")
ax1.set_xlabel("Year")
plt.legend()
plt.show()
