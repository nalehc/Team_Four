# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv("wage_year.csv"))
df.head()
# Out:
#    Year  Wage   Employment
# 0  2004  8.50  102781.0000
# 1  2005  8.62  104057.3333
# 2  2006  8.82  106236.3333
# 3  2007  9.14  109609.0833
# 4  2008  9.36  111379.1667

# %%
year = df["Year"]
wage = df["Wage"]
jobs = df["Employment"]

fig, ax1 = plt.subplots()
ax1.plot(year, wage, color = "#bd3161")
ax1.set_xlabel("Year")
ax1.set_ylabel("Wage", color="#bd3161")
ax1.tick_params("y", colors="#bd3161")

ax2 = ax1.twinx()
ax2.plot(year,jobs, color = "#f44e31")
ax2.set_ylabel("Number Employed", color="#f44e31")
ax2.tick_params("y", colors="#f44e31")

fig.tight_layout()
plt.show()

# %%
import statsmodels.formula.api as sm
model = sm.ols(formula="Employment ~ Wage", data = df)
fitted = model.fit()
print (fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Employment   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     54.65
# Date:                Sat, 09 Dec 2017   Prob (F-statistic):           8.36e-06
# Time:                        11:17:42   Log-Likelihood:                -135.13
# No. Observations:                  14   AIC:                             274.3
# Df Residuals:                      12   BIC:                             275.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.037e+04   7236.502      8.342      0.000    4.46e+04    7.61e+04
# Wage        5137.6566    694.996      7.392      0.000    3623.390    6651.923
# ==============================================================================
# Omnibus:                        0.352   Durbin-Watson:                   0.897
# Prob(Omnibus):                  0.839   Jarque-Bera (JB):                0.472
# Skew:                           0.052   Prob(JB):                        0.790
# Kurtosis:                       2.106   Cond. No.                         70.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/chelan/anaconda3/envs/python_data/lib/python3.5/site-packages/scipy/stats/stats.py:1390: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   "anyway, n=%i" % int(n))

# %%
plt.plot(df["Wage"], df["Employment"], 'ro')
plt.plot(df["Wage"], fitted.fittedvalues, 'b')
plt.legend(['Data', 'Fitted model'])
plt.ylim(min(jobs)-10000, max(jobs)+10000)
plt.xlim(min(wage)-1, max(wage)+1)
plt.xlabel('Minimum Wage Amount')
plt.ylabel('Number People Employed')
plt.title('Minimum Wage and Employment')
plt.show()
